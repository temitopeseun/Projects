# %% [markdown]
# ### Inspecting a webpage
#
# (You will need this to find links to individual songs in your artist's page.)

# %%
import requests

# %%
url = 'https://en.wikipedia.org/wiki/Michael_Jackson'

# %%
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.text[:1000])
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Michael Jackson - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"777b3184-4616-485a-9371-09e1eba4d0d0","wgCSPNonce":false,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":0,"wgPageName":"Michael_Jackson","wgTitle":"Michael Jackson","wgCurRevisionId":1098978349,"wgRevisionId":1098978349,"wgArticleId":14995351,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 French-language sources (fr)","All articles with dead external links","Articles with dead external links from June 2022","Articles with perman

# %%
import re

# %%
links = re.findall('href.{100}', response.text)
links
# Out:
# ['href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.tmh.player.styles%7Cext.uls.interlanguage%7C',
#  'href="/wiki/Wikipedia:Featured_articles" title="This is a featured article. Click here for more informat',
#  'href="/wiki/Wikipedia:Protection_policy#extended" title="This article is extended-confirmed protected"><',
#  'href="/wiki/File:En-Michael_Jackson-article.ogg" title="Listen to this article"><img alt="Listen to this',
#  'href="/wiki/Michael_Jackson_(disambiguation)" class="mw-disambig" title="Michael Jackson (disambiguation',
#  'href="mw-data:TemplateStyles:r1033289096"/><div role="note" class="hatnote navigation-not-searchable">"K',
#  'href="/wiki/King_of_Pop_(disambiguation)" class="mw-disambig" title="King of Pop (disambiguation)">King ',
#  'href="/wiki/File:Michael_Jackson_in_1988.jpg" class="image"><img alt="A photograph of Michael Jackson si',
#  'href="/wiki/Gary,_Indiana" title="Gary, Indiana">Gary, Indiana</a>, U.S.</div></td></tr><tr><th scope="r',
#  'href="/wiki/Death_of_Michael_Jackson" title="Death of Michael Jackson">Acute propofol and benzodiazepine',
#  'href="/wiki/Forest_Lawn_Memorial_Park_(Glendale)" title="Forest Lawn Memorial Park (Glendale)">Forest La',
#  'href="/wiki/Paris_Jackson" title="Paris Jackson">Paris</a></td></tr><tr><th scope="row" class="infobox-l',
#  'href="/wiki/Joe_Jackson_(manager)" title="Joe Jackson (manager)">Joe Jackson</a></li><li><a href="/wiki/',
#  'href="/wiki/Jackson_family" title="Jackson family">Jackson</a></td></tr><tr><th scope="row" class="infob',
#  'href="/wiki/List_of_awards_and_nominations_received_by_Michael_Jackson" title="List of awards and nomina',
#  'href="mw-data:TemplateStyles:r1066479718"/><b>Musical career</b></td></tr><tr><th scope="row" class="inf',
#  'href="/wiki/Pop_music" title="Pop music">Pop</a></li><li><a href="/wiki/Soul_music" title="Soul music">s',
#  'href="/wiki/Funk" title="Funk">funk</a></li><li><span class="nowrap"><a href="/wiki/Rhythm_and_blues" ti',
#  'href="/wiki/Rock_music" title="Rock music">rock</a></li><li><a href="/wiki/Disco" title="Disco">disco</a',
#  'href="/wiki/Post-disco" title="Post-disco">post-disco</a></li><li><span class="nowrap"><a href="/wiki/Da',
#  'href="/wiki/New_jack_swing" title="New jack swing">new jack swing</a></li></ul></div></td></tr><tr><th s',
#  'href="/wiki/Steeltown_Records" title="Steeltown Records">Steeltown</a></li><li><a href="/wiki/Motown" ti',
#  'href="/wiki/Epic_Records" title="Epic Records">Epic</a></li><li><a href="/wiki/Legacy_Recordings" title=',
#  'href="/wiki/Sony_Music" title="Sony Music">Sony</a></li><li>MJJ Productions</li></ul></div></td></tr><tr',
#  'href="http://michaeljackson.com">michaeljackson<wbr />.com</a></span></td></tr><tr><th colspan="2" class',
#  'href="/wiki/File:Michael_Jackson_signature.svg" class="image"><img alt="Michael Jackson signature.svg" s',
#  'href="/wiki/Honorific_nicknames_in_popular_music" title="Honorific nicknames in popular music">King of P',
#  'href="/wiki/Cultural_impact_of_Michael_Jackson" title="Cultural impact of Michael Jackson">one of the mo',
#  'href="/wiki/Popular_culture" title="Popular culture">popular culture</a>. Jackson influenced artists acr',
#  'href="/wiki/Moonwalk_(dance)" title="Moonwalk (dance)">moonwalk</a>, to which he gave the name, as well ',
#  'href="/wiki/Robot_(dance)" title="Robot (dance)">robot</a>. He is the <a href="/wiki/List_of_awards_and_',
#  'href="/wiki/Jackson_family" title="Jackson family">Jackson family</a>, Jackson made his professional deb',
#  'href="/wiki/Jackie_Jackson" title="Jackie Jackson">Jackie</a>, <a href="/wiki/Tito_Jackson" title="Tito ',
#  'href="/wiki/Jermaine_Jackson" title="Jermaine Jackson">Jermaine</a>, and <a href="/wiki/Marlon_Jackson" ',
#  'href="/wiki/The_Jackson_5" title="The Jackson 5">the Jackson 5</a> (later known as the Jacksons). Jackso',
#  'href="/wiki/Motown" title="Motown">Motown Records</a>. He became a solo star with his 1979 album <i><a h',
#  'href="/wiki/Michael_Jackson_videography" title="Michael Jackson videography">music videos</a>, including',
#  'href="/wiki/Beat_It" title="Beat It">Beat It</a>", "<a href="/wiki/Billie_Jean" title="Billie Jean">Bill',
#  'href="/wiki/Thriller_(song)" title="Thriller (song)">Thriller</a>" from his 1982 album <i><a href="/wiki',
#  'href="/wiki/Anti-black_racism_in_the_United_States" class="mw-redirect" title="Anti-black racism in the ',
#  'href="/wiki/MTV" title="MTV">MTV</a> and continued to innovate with videos for the albums <i><a href="/w',
#  'href="/wiki/Dangerous_(Michael_Jackson_album)" title="Dangerous (Michael Jackson album)">Dangerous</a></',
#  'href="/wiki/HIStory:_Past,_Present_and_Future,_Book_I" title="HIStory: Past, Present and Future, Book I"',
#  'href="/wiki/List_of_best-selling_albums" title="List of best-selling albums">best-selling album of all t',
#  'href="/wiki/Billboard_Hot_100" title="Billboard Hot 100"><i>Billboard</i> Hot 100</a> number-one singles',
#  'href="/wiki/Health_and_appearance_of_Michael_Jackson" title="Health and appearance of Michael Jackson">c',
#  'href="/wiki/Personal_relationships_of_Michael_Jackson" title="Personal relationships of Michael Jackson"',
#  'href="/wiki/1993_child_sexual_abuse_accusations_against_Michael_Jackson" title="1993 child sexual abuse ',
#  'href="/wiki/Trial_of_Michael_Jackson" title="Trial of Michael Jackson">tried and acquitted</a> of furthe',
#  'href="/wiki/FBI_files_on_Michael_Jackson" title="FBI files on Michael Jackson">FBI</a> found no evidence',
#  'href="/wiki/This_Is_It_(concert_residency)" title="This Is It (concert residency)">This Is It</a>, Jacks',
#  'href="/wiki/Death_of_Michael_Jackson" title="Death of Michael Jackson">died</a> from an overdose of <a h',
#  'href="/wiki/Conrad_Murray" title="Conrad Murray">Conrad Murray</a>, who was <a href="/wiki/California_v.',
#  'href="/wiki/Involuntary_manslaughter" class="mw-redirect" title="Involuntary manslaughter">involuntary m',
#  'href="/wiki/List_of_best-selling_music_artists" title="List of best-selling music artists">best-selling ',
#  'href="#cite_note-10">&#91;nb 2&#93;</a></sup> He had 13 <a href="/wiki/List_of_artists_by_number_of_Bill',
#  'href="/wiki/Recording_Industry_Association_of_America" title="Recording Industry Association of America"',
#  'href="/wiki/Grammy_Awards" title="Grammy Awards">Grammy Awards</a>, 6 <a href="/wiki/Brit_Awards" title=',
#  'href="/wiki/Golden_Globe_Award" class="mw-redirect" title="Golden Globe Award">Golden Globe Award</a>, a',
#  'href="/wiki/Guinness_World_Records" title="Guinness World Records">Guinness World Records</a>, including',
#  'href="/wiki/List_of_Rock_and_Roll_Hall_of_Fame_inductees" title="List of Rock and Roll Hall of Fame indu',
#  'href="/wiki/Vocal_Group_Hall_of_Fame" title="Vocal Group Hall of Fame">Vocal Group Hall of Fame</a>, the',
#  'href="/wiki/Songwriters_Hall_of_Fame" title="Songwriters Hall of Fame">Songwriters Hall of Fame</a>, the',
#  'href="/wiki/National_Museum_of_Dance_and_Hall_of_Fame" title="National Museum of Dance and Hall of Fame"',
#  'href="/wiki/Rhythm_and_Blues_Music_Hall_of_Fame" title="Rhythm and Blues Music Hall of Fame">Rhythm and ',
#  'href="#Life_and_career"><span class="tocnumber">1</span> <span class="toctext">Life and career</span></a',
#  'href="#Early_life_and_the_Jackson_5_(1958–1975)"><span class="tocnumber">1.1</span> <span class="toctext',
#  'href="#Move_to_Epic_and_Off_the_Wall_(1975–1981)"><span class="tocnumber">1.2</span> <span class="toctex',
#  'href="#Thriller_and_Motown_25:_Yesterday,_Today,_Forever_(1982–1983)"><span class="tocnumber">1.3</span>',
#  'href="#Pepsi_incident_and_other_commercial_activities_(1984–1985)"><span class="tocnumber">1.4</span> <s',
#  'href="#Increased_tabloid_spectulation_(1986–1987)"><span class="tocnumber">1.5</span> <span class="tocte',
#  'href="#Bad,_autobiography,_and_Neverland_(1987–1990)"><span class="tocnumber">1.6</span> <span class="to',
#  'href="#Dangerous_and_public_social_work_(1991–1993)"><span class="tocnumber">1.7</span> <span class="toc',
#  'href="#First_child_sexual_abuse_accusations_and_first_marriage_(1993–1995)"><span class="tocnumber">1.8<',
#  'href="#HIStory,_second_marriage,_and_fatherhood_(1995–1997)"><span class="tocnumber">1.9</span> <span cl',
#  'href="#Label_dispute_and_Invincible_(1997–2002)"><span class="tocnumber">1.10</span> <span class="toctex',
#  'href="#Second_child_abuse_allegations_and_acquittal_(2002–2005)"><span class="tocnumber">1.11</span> <sp',
#  'href="#Final_years_and_This_Is_It_(2006–2009)"><span class="tocnumber">1.12</span> <span class="toctext"',
#  'href="#Memorial_service"><span class="tocnumber">2.1</span> <span class="toctext">Memorial service</span',
#  'href="#Criminal_investigation_and_prosecution_of_Conrad_Murray"><span class="tocnumber">2.2</span> <span',
#  'href="#Posthumous_sales"><span class="tocnumber">2.3</span> <span class="toctext">Posthumous sales</span',
#  'href="#Posthumous_releases_and_productions"><span class="tocnumber">2.4</span> <span class="toctext">Pos',
#  'href="#Posthumous_child_sexual_abuse_allegations"><span class="tocnumber">2.5</span> <span class="toctex',
#  'href="#Vocal_style"><span class="tocnumber">4.2</span> <span class="toctext">Vocal style</span></a></li>',
#  'href="#Musicianship"><span class="tocnumber">4.3</span> <span class="toctext">Musicianship</span></a></l',
#  'href="#Themes_and_genres"><span class="tocnumber">4.5</span> <span class="toctext">Themes and genres</sp',
#  'href="#Music_videos_and_choreography"><span class="tocnumber">4.6</span> <span class="toctext">Music vid',
#  'href="#Honors_and_awards"><span class="tocnumber">5</span> <span class="toctext">Honors and awards</span',
#  'href="#Print_sources"><span class="tocnumber">11.2</span> <span class="toctext">Print sources</span></a>',
#  'href="#Further_reading"><span class="tocnumber">12</span> <span class="toctext">Further reading</span></',
#  'href="#External_links"><span class="tocnumber">13</span> <span class="toctext">External links</span></a>',
#  'href="/wiki/File:2300_Jackson_Street_Yuksel.jpg" class="image"><img alt="The single-story house has whit',
#  'href="/wiki/File:2300_Jackson_Street_Yuksel.jpg" class="internal" title="Enlarge"></a></div>Jackson\'s ch',
#  'href="/wiki/Gary,_Indiana" title="Gary, Indiana">Gary, Indiana</a>, pictured in March 2010</div></div></',
#  'href="#cite_note-certificate-11">&#91;9&#93;</a></sup><sup id="cite_ref-allmusic_12-0" class="reference"',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup> was born in <a href="/wiki/Gary,_Indiana" title="Ga',
#  'href="#cite_note-Barnes-13">&#91;11&#93;</a></sup><sup id="cite_ref-14" class="reference"><a href="#cite',
#  'href="/wiki/Jackson_family" title="Jackson family">Jackson family</a>, a working-class <a href="/wiki/Af',
#  'href="#cite_note-FOOTNOTEJackson200926-15">&#91;13&#93;</a></sup><sup id="cite_ref-FOOTNOTEYoung200918_1',
#  'href="#cite_note-FOOTNOTEYoung200918-16">&#91;14&#93;</a></sup> His mother, <a href="/wiki/Katherine_Jac',
#  'href="/wiki/Country_music" title="Country music">country-and-western</a> performer, and worked part-time',
#  'href="/wiki/Sears" title="Sears">Sears</a>.<sup id="cite_ref-FOOTNOTEYoung200917,_19_17-0" class="refere',
#  'href="#cite_note-FOOTNOTEYoung200917,_19-17">&#91;15&#93;</a></sup> She was a <a href="/wiki/Jehovah%27s',
#  'href="#cite_note-monstrous-18">&#91;16&#93;</a></sup> His father, <a href="/wiki/Joe_Jackson_(manager)" ',
#  'href="/wiki/U.S._Steel" title="U.S. Steel">U.S. Steel</a> and played guitar with a local <a href="/wiki/',
#  'href="#cite_note-Obit_Guardian-19">&#91;17&#93;</a></sup><sup id="cite_ref-FOOTNOTEYoung200918–19_20-0" ',
#  'href="#cite_note-FOOTNOTEYoung200918–19-20">&#91;18&#93;</a></sup> Joe\'s great-grandfather, July "Jack" ',
#  'href="/wiki/Cavalry_scout" title="Cavalry scout">scout</a>; family lore held that he was also a Native A',
#  'href="/wiki/Medicine_man" title="Medicine man">medicine man</a>.<sup id="cite_ref-FOOTNOTEKnopper20166._',
#  'href="#cite_note-FOOTNOTEKnopper20166._Note:_No_tribal_affiliation_named_in_source-21">&#91;19&#93;</a><',
#  'href="/wiki/Rebbie_Jackson" title="Rebbie Jackson">Rebbie</a>, <a href="/wiki/La_Toya_Jackson" title="La',
#  'href="/wiki/Janet_Jackson" title="Janet Jackson">Janet</a>) and five brothers (<a href="/wiki/Jackie_Jac',
#  'href="/wiki/Tito_Jackson" title="Tito Jackson">Tito</a>, <a href="/wiki/Jermaine_Jackson" title="Jermain',
#  'href="/wiki/Marlon_Jackson" title="Marlon Jackson">Marlon</a>, and <a href="/wiki/Randy_Jackson_(The_Jac',
#  'href="#cite_note-Obit_Guardian-19">&#91;17&#93;</a></sup> A sixth brother, Marlon\'s twin Brandon, died s',
#  'href="/wiki/Conga" title="Conga">congas</a> and <a href="/wiki/Tambourine" title="Tambourine">tambourine',
#  'href="#cite_note-23">&#91;21&#93;</a></sup><sup id="cite_ref-24" class="reference"><a href="#cite_note-2',
#  'href="#cite_note-bbcnews-25">&#91;23&#93;</a></sup> and physically and emotionally abused him during reh',
#  'href="#cite_note-monstrous-18">&#91;16&#93;</a></sup><sup id="cite_ref-FOOTNOTELewis_Jones2005165–168_26',
#  'href="#cite_note-FOOTNOTELewis_Jones2005165–168-26">&#91;24&#93;</a></sup> Joe acknowledged that he regu',
#  'href="#cite_note-27">&#91;25&#93;</a></sup> Katherine said that although whipping came to be considered ',
#  'href="#cite_note-28">&#91;26&#93;</a></sup><sup id="cite_ref-29" class="reference"><a href="#cite_note-2',
#  'href="#cite_note-30">&#91;28&#93;</a></sup> Jackson said his youth was lonely and isolated.<sup id="cite',
#  'href="/wiki/The_Jackson_5" title="The Jackson 5">the Jackson 5</a>.<sup id="cite_ref-32" class="referenc',
#  'href="#cite_note-32">&#91;30&#93;</a></sup> In 1965, the group won a talent show; Michael performed the ',
#  'href="/wiki/Robert_Parker_(singer)" title="Robert Parker (singer)">Robert Parker</a>\'s 1965 song "<a hre',
#  'href="/wiki/The_Temptations" title="The Temptations">the Temptations</a>\' "<a href="/wiki/My_Girl_(The_T',
#  'href="#cite_note-FOOTNOTETaraborrelli200913–14-33">&#91;31&#93;</a></sup> From 1966 to 1968, the Jackson',
#  'href="/wiki/Midwestern_United_States" title="Midwestern United States">Midwest</a>; they frequently play',
#  'href="/wiki/Chitlin%27_Circuit" title="Chitlin&#39; Circuit">Chitlin\' Circuit</a> as the opening act for',
#  'href="/wiki/Sam_%26_Dave" title="Sam &amp; Dave">Sam &amp; Dave</a>, <a href="/wiki/The_O%27Jays" title=',
#  'href="/wiki/Gladys_Knight" title="Gladys Knight">Gladys Knight</a>, and <a href="/wiki/Etta_James" title',
#  'href="/wiki/Striptease" title="Striptease">striptease</a> shows were featured, and at local auditoriums ',
#  'href="#cite_note-FOOTNOTEYoung200921–22-34">&#91;32&#93;</a></sup><sup id="cite_ref-35" class="reference',
#  'href="#cite_note-35">&#91;33&#93;</a></sup> In August 1967, while touring the <a href="/wiki/Eastern_Uni',
#  'href="/wiki/Apollo_Theater" title="Apollo Theater">Apollo Theater</a> in <a href="/wiki/Harlem" title="H',
#  'href="/wiki/File:Jackson_5_tv_special_1972.JPG" class="image"><img alt="" src="//upload.wikimedia.org/wi',
#  'href="/wiki/File:Jackson_5_tv_special_1972.JPG" class="internal" title="Enlarge"></a></div>Jackson (cent',
#  'href="/wiki/African_Americans" title="African Americans">African American</a> performers to attain a cro',
#  'href="/wiki/Steeltown_Records" title="Steeltown Records">Steeltown Records</a>; their first single, "<a ',
#  'href="/wiki/Big_Boy_(song)" title="Big Boy (song)">Big Boy</a>", was released in 1968.<sup id="cite_ref-',
#  'href="#cite_note-FOOTNOTEYoung200921-38">&#91;36&#93;</a></sup> Bobby Taylor of <a href="/wiki/Bobby_Tay',
#  'href="/wiki/Motown" title="Motown">Motown</a> after they opened for Taylor at Chicago\'s <a href="/wiki/R',
#  'href="/wiki/Who%27s_Lovin%27_You" title="Who&#39;s Lovin&#39; You">Who\'s Lovin\' You</a>".<sup id="cite_r',
#  'href="#cite_note-39">&#91;37&#93;</a></sup> After signing with Motown, the Jackson family relocated to L',
#  'href="#cite_note-FOOTNOTETaraborrelli200959–69-40">&#91;38&#93;</a></sup> In 1969, Motown executives dec',
#  'href="/wiki/Diana_Ross" title="Diana Ross">Diana Ross</a> should introduce the Jackson 5 to the public—p',
#  'href="#cite_note-41">&#91;39&#93;</a></sup> The Jackson 5 made their first television appearance in 1969',
#  'href="/wiki/Miss_Black_America" title="Miss Black America">Miss Black America</a> pageant, performing a ',
#  'href="/wiki/It%27s_Your_Thing" title="It&#39;s Your Thing">It\'s Your Thing</a>".<sup id="cite_ref-42" cl',
#  'href="#cite_note-42">&#91;40&#93;</a></sup> <i><a href="/wiki/Rolling_Stone" title="Rolling Stone">Rolli',
#  'href="/wiki/I_Want_You_Back" title="I Want You Back">I Want You Back</a>" became the first Jackson 5 son',
#  'href="/wiki/Billboard_Hot_100" title="Billboard Hot 100"><i>Billboard</i> Hot 100</a>; it stayed there f',
#  'href="/wiki/ABC_(The_Jackson_5_song)" title="ABC (The Jackson 5 song)">ABC</a>", "<a href="/wiki/The_Lov',
#  'href="/wiki/I%27ll_Be_There_(The_Jackson_5_song)" class="mw-redirect" title="I&#39;ll Be There (The Jack',
#  'href="#cite_note-44">&#91;42&#93;</a></sup> In May 1971, the Jackson family moved into a large house in ',
#  'href="/wiki/Hayvenhurst" title="Hayvenhurst">Hayvenhurst</a>, a two-acre estate in <a href="/wiki/Encino',
#  'href="#cite_note-FOOTNOTETaraborrelli200981–82-45">&#91;43&#93;</a></sup> During this period, Michael de',
#  'href="/wiki/Teen_idol" title="Teen idol">teen idol</a>.<sup id="cite_ref-FOOTNOTEYoung200925_46-0" class',
#  'href="#cite_note-FOOTNOTEYoung200925-46">&#91;44&#93;</a></sup> Between 1972 and 1975, he released four ',
#  'href="/wiki/Got_to_Be_There" title="Got to Be There">Got to Be There</a></i> (1972), <i><a href="/wiki/B',
#  'href="/wiki/Music_%26_Me" title="Music &amp; Me">Music &amp; Me</a></i> (1973), and <i><a href="/wiki/Fo',
#  'href="#cite_note-McNulty-47">&#91;45&#93;</a></sup> "<a href="/wiki/Got_to_Be_There_(song)" title="Got t',
#  'href="/wiki/Ben_(song)" title="Ben (song)">Ben</a>", the title tracks from his first two solo albums, so',
#  'href="/wiki/Bobby_Day" title="Bobby Day">Bobby Day</a>\'s "<a href="/wiki/Rockin%27_Robin_(song)" title="',
#  'href="#cite_note-McNulty-47">&#91;45&#93;</a></sup> The Jackson 5 were later described as "a cutting-edg',
#  'href="/wiki/Crossover_music" title="Crossover music">crossover artists</a>".<sup id="cite_ref-49" class=',
#  'href="#cite_note-49">&#91;47&#93;</a></sup> They were frustrated by Motown\'s refusal to allow them creat',
#  'href="#cite_note-50">&#91;48&#93;</a></sup> Jackson\'s performance of their top five single "<a href="/wi',
#  'href="/wiki/Soul_Train" title="Soul Train">Soul Train</a></i> popularized the <a href="/wiki/Robot_(danc',
#  'href="/wiki/File:Jackson_siblings_1977.jpg" class="image"><img alt="" src="//upload.wikimedia.org/wikipe',
#  'href="/wiki/File:Jackson_siblings_1977.jpg" class="internal" title="Enlarge"></a></div>The Jackson sibli',
#  'href="/wiki/Jackie_Jackson" title="Jackie Jackson">Jackie</a>, Michael, <a href="/wiki/Tito_Jackson" tit',
#  'href="/wiki/Marlon_Jackson" title="Marlon Jackson">Marlon</a>. Middle row: <a href="/wiki/Randy_Jackson_',
#  'href="/wiki/La_Toya_Jackson" title="La Toya Jackson">La Toya</a>, <a href="/wiki/Rebbie_Jackson" title="',
#  'href="/wiki/Epic_Records" title="Epic Records">Epic Records</a> and renaming themselves the Jacksons.<su',
#  'href="#cite_note-52">&#91;50&#93;</a></sup> Their younger brother Randy joined the band around this time',
#  'href="#cite_note-FOOTNOTETaraborrelli2009138–144-53">&#91;51&#93;</a></sup> The Jacksons continued to to',
#  'href="/wiki/Shake_Your_Body_(Down_to_the_Ground)" title="Shake Your Body (Down to the Ground)">Shake You',
#  'href="/wiki/This_Place_Hotel" title="This Place Hotel">This Place Hotel</a>" (1980), and "<a href="/wiki',
#  'href="/wiki/Scarecrow_(Oz)" title="Scarecrow (Oz)">Scarecrow</a> in <i><a href="/wiki/The_Wiz_(film)" ti',
#  'href="/wiki/Sidney_Lumet" title="Sidney Lumet">Sidney Lumet</a>, alongside <a href="/wiki/Diana_Ross" ti',
#  'href="/wiki/Nipsey_Russell" title="Nipsey Russell">Nipsey Russell</a>, and Ted Ross.<sup id="cite_ref-55',
#  'href="#cite_note-55">&#91;53&#93;</a></sup> The film was a box-office failure.<sup id="cite_ref-FOOTNOTE',
#  'href="#cite_note-FOOTNOTETaraborrelli2009178–179-56">&#91;54&#93;</a></sup> Its score was arranged by <a',
#  'href="/wiki/Quincy_Jones" title="Quincy Jones">Quincy Jones</a>,<sup id="cite_ref-FOOTNOTEBronson2003207',
#  'href="#cite_note-FOOTNOTEBronson2003207-57">&#91;55&#93;</a></sup> who later produced three of Jackson\'s',
#  'href="#cite_note-Who&#39;s_Bad-58">&#91;56&#93;</a></sup> During his time in New York, Jackson frequente',
#  'href="/wiki/Studio_54" title="Studio 54">Studio 54</a> nightclub, where he heard early <a href="/wiki/Hi',
#  'href="/wiki/Beatboxing" title="Beatboxing">beatboxing</a> on future tracks such as "<a href="/wiki/Worki',
#  'href="#cite_note-59">&#91;57&#93;</a></sup> In 1978, Jackson broke his nose during a dance routine. A <a',
#  'href="/wiki/Rhinoplasty" title="Rhinoplasty">rhinoplasty</a> led to breathing difficulties that later af',
#  'href="/wiki/Steven_Hoefflin" title="Steven Hoefflin">Steven Hoefflin</a>, who performed Jackson\'s operat',
#  'href="/wiki/Off_the_Wall" title="Off the Wall">Off the Wall</a></i> (1979), established him as a solo pe',
#  'href="/wiki/Bubblegum_music" title="Bubblegum music">bubblegum</a> pop of his youth to more complex soun',
#  'href="#cite_note-FOOTNOTEYoung200925-46">&#91;44&#93;</a></sup> It produced four top 10 entries in the U',
#  'href="/wiki/Off_the_Wall_(Michael_Jackson_song)" title="Off the Wall (Michael Jackson song)">Off the Wal',
#  'href="/wiki/She%27s_Out_of_My_Life" title="She&#39;s Out of My Life">She\'s Out of My Life</a>", and the ',
#  'href="/wiki/Don%27t_Stop_%27Til_You_Get_Enough" title="Don&#39;t Stop &#39;Til You Get Enough">Don\'t Sto',
#  'href="/wiki/Rock_with_You_(Michael_Jackson_song)" class="mw-redirect" title="Rock with You (Michael Jack',
#  'href="#cite_note-FourUSTop10s-61">&#91;59&#93;</a></sup> The album reached number three on the US <a hre',
#  'href="#cite_note-62">&#91;60&#93;</a></sup> In 1980, Jackson won three <a href="/wiki/American_Music_Awa',
#  'href="#cite_note-63">&#91;61&#93;</a></sup><sup id="cite_ref-64" class="reference"><a href="#cite_note-6',
#  'href="#cite_note-grammy_mj-65">&#91;63&#93;</a></sup> In 1981, Jackson was the American Music Awards win',
#  'href="#cite_note-66">&#91;64&#93;</a></sup> Jackson felt <i>Off the Wall</i> should have made a bigger i',
#  'href="#cite_note-FOOTNOTETaraborrelli2009188-67">&#91;65&#93;</a></sup> In 1980, he secured the highest ',
#  'href="/wiki/Royalties" class="mw-redirect" title="Royalties">royalty</a> rate in the music industry: 37 ',
#  'href="/wiki/File:Michael_Jackson%27s_Glove_and_Cardigan.jpg" class="image"><img alt="A sparkly jacket an',
#  'href="/wiki/File:Michael_Jackson%27s_Glove_and_Cardigan.jpg" class="internal" title="Enlarge"></a></div>',
#  'href="/wiki/Motown_25:_Yesterday,_Today,_Forever" title="Motown 25: Yesterday, Today, Forever">Motown 25',
#  'href="/wiki/British_Vogue" title="British Vogue">British Vogue</a></i> called Jackson "a fashion pioneer',
#  'href="/wiki/Moonwalk_(dance)" title="Moonwalk (dance)">moonwalking</a>, immortalised solitary, [and] spa',
#  'href="/wiki/Queen_(band)" title="Queen (band)">Queen</a> singer <a href="/wiki/Freddie_Mercury" title="F',
#  'href="/wiki/State_of_Shock_(song)" title="State of Shock (song)">State of Shock</a>", "Victory" and "<a ',
#  'href="/wiki/There_Must_Be_More_to_Life_Than_This" title="There Must Be More to Life Than This">There Mus',
#  'href="/wiki/Jim_Beach" title="Jim Beach">Jim Beach</a>, the relationship soured when Jackson brought a <',
#  'href="/wiki/Llama" title="Llama">llama</a> into the recording studio,<sup id="cite_ref-70" class="refere',
#  'href="#cite_note-70">&#91;68&#93;</a></sup> and Jackson was upset by Mercury\'s drug use.<sup id="cite_re',
#  'href="#cite_note-71">&#91;69&#93;</a></sup> The songs were released in 2014.<sup id="cite_ref-Greene_72-',
#  'href="#cite_note-Greene-72">&#91;70&#93;</a></sup> Jackson went on to record "State of Shock" with <a hr',
#  'href="/wiki/Victory_(The_Jacksons_album)" title="Victory (The Jacksons album)">Victory</a></i> (1984).<s',
#  'href="#cite_note-73">&#91;71&#93;</a></sup> In 1982, Jackson contributed "Someone in the Dark" to the <a',
#  'href="/wiki/E.T._the_Extra-Terrestrial_(album)" title="E.T. the Extra-Terrestrial (album)">audiobook for',
#  'href="/wiki/Thriller_(Michael_Jackson_album)" class="mw-redirect" title="Thriller (Michael Jackson album',
#  'href="#cite_note-74">&#91;72&#93;</a></sup><sup id="cite_ref-75" class="reference"><a href="#cite_note-7',
#  'href="#cite_note-76">&#91;74&#93;</a></sup> and the <a href="/wiki/List_of_best-selling_albums" title="L',
#  'href="#cite_note-77">&#91;75&#93;</a></sup><sup id="cite_ref-78" class="reference"><a href="#cite_note-7',
#  'href="/wiki/Billie_Jean" title="Billie Jean">Billie Jean</a>", "<a href="/wiki/Beat_It" title="Beat It">',
#  'href="/wiki/Wanna_Be_Startin%27_Somethin%27" title="Wanna Be Startin&#39; Somethin&#39;">Wanna Be Starti',
#  'href="/wiki/Motown_25:_Yesterday,_Today,_Forever" title="Motown 25: Yesterday, Today, Forever">Motown 25',
#  'href="#cite_note-80">&#91;78&#93;</a></sup> Jackson\'s solo performance of "Billie Jean" earned him his f',
#  'href="/wiki/Emmy_Award" class="mw-redirect" title="Emmy Award">Emmy Award</a> nomination.<sup id="cite_r',
#  'href="#cite_note-emmys.tv-81">&#91;79&#93;</a></sup> Wearing a glove decorated with <a href="/wiki/Rhine',
#  'href="#cite_note-82">&#91;80&#93;</a></sup> he debuted his <a href="/wiki/Moonwalk_(dance)" title="Moonw',
#  'href="/wiki/Jeffrey_Daniel" title="Jeffrey Daniel">Jeffrey Daniel</a> had taught him three years earlier',
#  'href="#cite_note-Daniel-83">&#91;81&#93;</a></sup> Jackson had originally turned down the invitation to ',
#  'href="/wiki/Berry_Gordy" title="Berry Gordy">Berry Gordy</a>, he performed in exchange for an opportunit',
#  'href="#cite_note-FOOTNOTETaraborrelli2009234–237-84">&#91;82&#93;</a></sup> <i>Rolling Stone</i> reporte',
#  'href="#cite_note-FOOTNOTEYoung200925-46">&#91;44&#93;</a></sup> Jackson\'s performance drew comparisons t',
#  'href="/wiki/Elvis_Presley" title="Elvis Presley">Elvis Presley</a>\'s and <a href="/wiki/The_Beatles" tit',
#  'href="/wiki/The_Ed_Sullivan_Show" title="The Ed Sullivan Show">The Ed Sullivan Show</a></i>.<sup id="cit',
#  'href="#cite_note-FOOTNOTETaraborrelli2009238–241-85">&#91;83&#93;</a></sup> <a href="/wiki/Anna_Kisselgo',
#  'href="#cite_note-86">&#91;84&#93;</a></sup> Gordy described being "mesmerized" by the performance.<sup i',
#  'href="/wiki/26th_Annual_Grammy_Awards" title="26th Annual Grammy Awards">26th Annual Grammy Awards</a>, ',
#  'href="/wiki/Santana_(band)" title="Santana (band)">Santana</a>.<sup id="cite_ref-grammy_mj_65-1" class="',
#  'href="#cite_note-grammy_mj-65">&#91;63&#93;</a></sup> Jackson and Quincy Jones won the award for Produce',
#  'href="#cite_note-grammy_mj-65">&#91;63&#93;</a></sup> <i>Thriller</i> won the Grammy for Best Engineered',
#  'href="/wiki/Bruce_Swedien" title="Bruce Swedien">Bruce Swedien</a> for his work on the album.<sup id="ci',
#  'href="#cite_note-Bruce-88">&#91;86&#93;</a></sup> At the <a href="/wiki/American_Music_Awards_of_1984" t',
#  'href="#cite_note-Awards_1984-89">&#91;87&#93;</a></sup> He also won Favorite Male Artist, Favorite Soul/',
#  'href="#cite_note-Awards_1984-89">&#91;87&#93;</a></sup><sup id="cite_ref-90" class="reference"><a href="',
#  'href="/wiki/Michael_Jackson%27s_Thriller_(music_video)" title="Michael Jackson&#39;s Thriller (music vid',
#  'href="#cite_note-91">&#91;89&#93;</a></sup><sup id="cite_ref-Griffin_92-0" class="reference"><a href="#c',
#  'href="#cite_note-Griffin-92">&#91;90&#93;</a></sup> Jackson had the highest royalty rate in the music in',
#  'href="#cite_note-Time-93">&#91;91&#93;</a></sup> In the same year, <i>The Making of Michael Jackson\'s Th',
#  'href="#cite_note-grammy_mj-65">&#91;63&#93;</a></sup> <i>Time</i> described Jackson\'s influence at that ',
#  'href="#cite_note-Time-93">&#91;91&#93;</a></sup> <i>The New York Times</i> wrote "in the world of pop mu',
#  'href="/wiki/Ronald_Reagan" title="Ronald Reagan">Ronald Reagan</a> gave Jackson an award recognizing his',
#  'href="#cite_note-FOOTNOTETaraborrelli2009304–307-95">&#91;93&#93;</a></sup> and in recognition of his su',
#  'href="/wiki/Ad_Council" title="Ad Council">Ad Council</a>\'s and the <a href="/wiki/National_Highway_Traf',
#  'href="#cite_note-96">&#91;94&#93;</a></sup><style data-mw-deduplicate="TemplateStyles:r1096954695/mw-par',
#  'href="/wiki/File:Reagans_with_Michael_Jackson.jpg" class="image"><img alt="" src="//upload.wikimedia.org',
#  'href="/wiki/Ronald_Reagan" title="Ronald Reagan">President Ronald Reagan</a> and <a href="/wiki/Nancy_Re',
#  'href="/wiki/White_House" title="White House">White House</a> on May 14, 1984</div></div></div><div class',
#  'href="/wiki/File:Michael_Jackson_Reagan_Pete_Souza_1984.jpg" class="image"><img alt="" src="//upload.wik',
#  'href="/wiki/PepsiCo" title="PepsiCo">PepsiCo</a> in a $5<span class="nowrap">&#160;</span>million promot',
#  'href="/wiki/Jingle" title="Jingle">jingle</a>.<sup id="cite_ref-Herrera2_97-0" class="reference"><a href',
#  'href="/wiki/Phil_Dusenberry" title="Phil Dusenberry">Phil Dusenberry</a>,<sup id="cite_ref-98" class="re',
#  'href="#cite_note-98">&#91;96&#93;</a></sup> a <a href="/wiki/BBDO" title="BBDO">BBDO</a> ad agency execu',
#  'href="/wiki/Alan_Pottasch" title="Alan Pottasch">Alan Pottasch</a>, Pepsi\'s Worldwide Creative Director,',
#  'href="/wiki/Shrine_Auditorium" title="Shrine Auditorium">Shrine Auditorium</a> in Los Angeles. During a ',
#  'href="/wiki/Burn" title="Burn">second-degree burns</a> to his scalp. Jackson underwent treatment to hide',
#  'href="#cite_note-99">&#91;97&#93;</a></sup> Pepsi settled out of court, and Jackson donated the $1.5<spa',
#  'href="/wiki/Southern_California_Hospital_at_Culver_City" title="Southern California Hospital at Culver C',
#  'href="/wiki/Culver_City,_California" title="Culver City, California">Culver City, California</a>; its no',
#  'href="#cite_note-FOOTNOTETaraborrelli2009279–287-100">&#91;98&#93;</a></sup><sup id="cite_ref-101" class',
#  'href="#cite_note-101">&#91;99&#93;</a></sup> Jackson signed a second agreement with Pepsi in the late 19',
#  'href="/wiki/LA_Gear" title="LA Gear">LA Gear</a>, <a href="/wiki/Suzuki" title="Suzuki">Suzuki</a>, and ',
#  'href="/wiki/Sony" title="Sony">Sony</a>, but none were as significant as his deals with Pepsi.<sup id="c',
#  'href="/wiki/Victory_Tour_(The_Jacksons_tour)" title="Victory Tour (The Jacksons tour)">Victory Tour</a> ',
#  'href="#cite_note-102">&#91;100&#93;</a></sup> Following <a href="/wiki/Victory_Tour_(The_Jacksons_tour)#',
#  'href="#cite_note-103">&#91;101&#93;</a></sup> During the last concert of the Victory Tour at the <a href',
#  'href="#cite_note-104">&#91;102&#93;</a></sup> His charitable work continued with the release of "<a href',
#  'href="/wiki/Lionel_Richie" title="Lionel Richie">Lionel Richie</a>,<sup id="cite_ref-WATW_105-0" class="',
#  'href="#cite_note-WATW-105">&#91;103&#93;</a></sup> which raised money for the poor in the US and Africa.',
#  'href="#cite_note-jdoyle-106">&#91;104&#93;</a></sup> It earned $63<span class="nowrap">&#160;</span>mill',
#  'href="#cite_note-jdoyle-106">&#91;104&#93;</a></sup> and became one of the <a href="/wiki/List_of_best-s',
#  'href="#cite_note-107">&#91;105&#93;</a></sup> It won four Grammy Awards in 1985, including Song of the Y',
#  'href="#cite_note-WATW-105">&#91;103&#93;</a></sup> The project\'s creators received two special American ',
#  'href="/wiki/USA_for_Africa" class="mw-redirect" title="USA for Africa">USA for Africa</a> idea. Jackson,',
#  'href="#cite_note-WATW-105">&#91;103&#93;</a></sup><sup id="cite_ref-AMAs_1986_108-0" class="reference"><',
#  'href="#cite_note-AMAs_1986-108">&#91;106&#93;</a></sup><sup id="cite_ref-FOOTNOTECampbell1993114_109-0" ',
#  'href="#cite_note-FOOTNOTECampbell1993114-109">&#91;107&#93;</a></sup><sup id="cite_ref-FOOTNOTEYoung2009',
#  'href="/wiki/File:Michael_Jackson_autographing_%27We_Are_The_World%27_posters_1985.jpg" class="image"><im',
#  'href="/wiki/File:Michael_Jackson_autographing_%27We_Are_The_World%27_posters_1985.jpg" class="internal" ',
#  'href="/wiki/We_Are_the_World" title="We Are the World">We Are the World</a>" poster in 1985</div></div><',
#  'href="/wiki/Paul_McCartney" title="Paul McCartney">Paul McCartney</a> in the early 1980s, and learned th',
#  'href="#cite_note-jdoyle-106">&#91;104&#93;</a></sup> By 1983, Jackson had begun buying publishing rights',
#  'href="/wiki/Music_catalog" title="Music catalog">music catalogs</a> and song copyrights such as the <a h',
#  'href="/wiki/Len_Barry" title="Len Barry">Len Barry</a>\'s "<a href="/wiki/1-2-3_(Len_Barry_song)" title="',
#  'href="/wiki/Dion_DiMucci" title="Dion DiMucci">Dion DiMucci</a>\'s "<a href="/wiki/The_Wanderer_(Dion_son',
#  'href="/wiki/Robert_Holmes_%C3%A0_Court" title="Robert Holmes à Court">Robert Holmes à Court</a> announce',
#  'href="/wiki/Sony/ATV_Music_Publishing#Acquisition" class="mw-redirect" title="Sony/ATV Music Publishing"',
#  'href="#cite_note-hilburn-111">&#91;109&#93;</a></sup> In 1981, McCartney had been offered the catalog fo',
#  'href="#cite_note-jdoyle-106">&#91;104&#93;</a></sup><sup id="cite_ref-mcca_atv_112-0" class="reference">',
#  'href="#cite_note-mcca_atv-112">&#91;110&#93;</a></sup> Jackson submitted a bid of $46<span class="nowrap',
#  'href="#cite_note-hilburn-111">&#91;109&#93;</a></sup> When Jackson and McCartney were unable to make a j',
#  'href="#cite_note-FOOTNOTETaraborrelli2009333–338-113">&#91;111&#93;</a></sup><sup id="cite_ref-mcca_atv_',
#  'href="#cite_note-mcca_atv-112">&#91;110&#93;</a></sup> Jackson\'s agents were unable to come to a deal, a',
#  'href="/wiki/Due_diligence" title="Due diligence">due diligence</a> work on the negotiations.<sup id="cit',
#  'href="#cite_note-hilburn-111">&#91;109&#93;</a></sup> In June 1985, Jackson and Branca learned that <a h',
#  'href="/wiki/Martin_Bandier" title="Martin Bandier">Marty Bandier</a>\'s The Entertainment Company had mad',
#  'href="#cite_note-hilburn-111">&#91;109&#93;</a></sup> Jackson agreed to visit Holmes à Court in Australi',
#  'href="/wiki/Channel_Seven_Perth_Telethon" title="Channel Seven Perth Telethon">Channel Seven Perth Telet',
#  'href="#cite_note-ch7news-114">&#91;112&#93;</a></sup> His purchase of ATV Music was finalized on August ',
#  'href="#cite_note-jdoyle-106">&#91;104&#93;</a></sup><sup id="cite_ref-hilburn_111-4" class="reference"><',
#  'href="mw-data:TemplateStyles:r1033289096"/><div role="note" class="hatnote navigation-not-searchable">Se',
#  'href="/wiki/Health_and_appearance_of_Michael_Jackson" title="Health and appearance of Michael Jackson">H',
#  'href="/wiki/Skin_whitening" title="Skin whitening">bleaching his skin</a>.<sup id="cite_ref-FOOTNOTECamp',
#  'href="#cite_note-FOOTNOTECampbell199514–16-115">&#91;113&#93;</a></sup><sup id="cite_ref-FOOTNOTEParames',
#  'href="#cite_note-FOOTNOTEParameswaran201175–77-116">&#91;114&#93;</a></sup><sup id="cite_ref-FOOTNOTEDeM',
#  'href="#cite_note-FOOTNOTEDeMello2012152-117">&#91;115&#93;</a></sup> His dermatologist, <a href="/wiki/A',
#  'href="/wiki/Vitiligo" title="Vitiligo">vitiligo</a>,<sup id="cite_ref-Rosenberg_118-0" class="reference"',
#  'href="#cite_note-Rosenberg-118">&#91;116&#93;</a></sup> a condition characterized by patches of the skin',
#  'href="/wiki/Discoid_lupus_erythematosus" title="Discoid lupus erythematosus">discoid lupus erythematosus',
#  'href="#cite_note-Rosenberg-118">&#91;116&#93;</a></sup> and with vitiligo in 1986.<sup id="cite_ref-119"',
#  'href="#cite_note-119">&#91;117&#93;</a></sup> Vitiligo\'s drastic effects on the body can cause psycholog',
#  'href="#cite_note-120">&#91;118&#93;</a></sup> and possibly skin-bleaching prescription creams,<sup id="c',
#  'href="#cite_note-121">&#91;119&#93;</a></sup> to cover up the uneven blotches of color caused by the ill',
#  'href="#cite_note-FOOTNOTETaraborrelli2009434–436-122">&#91;120&#93;</a></sup> Jackson said he had not pu',
#  'href="#cite_note-Oprah-Jackson-123">&#91;121&#93;</a></sup> He became friends with Klein and Klein\'s ass',
#  'href="/wiki/Debbie_Rowe" title="Debbie Rowe">Debbie Rowe</a>. Rowe later became Jackson\'s second wife an',
#  'href="/wiki/Rhinoplasty" title="Rhinoplasty">rhinoplasty</a> surgeries and a <a href="/wiki/Cleft_chin" ',
#  'href="#cite_note-FOOTNOTEJackson2009229–230-125">&#91;123&#93;</a></sup> Witnesses reported that he was ',
#  'href="/wiki/Anorexia_nervosa" title="Anorexia nervosa">anorexia nervosa</a>. Periods of weight loss beca',
#  'href="#cite_note-FOOTNOTETaraborrelli2009312–313-126">&#91;124&#93;</a></sup> After his death, Jackson\'s',
#  'href="/wiki/Plastic_surgery#Cosmetic_surgery_procedures" title="Plastic surgery">cosmetic procedures</a>',
#  'href="/wiki/Tabloid_journalism" title="Tabloid journalism">tabloids</a> reported that Jackson slept in a',
#  'href="/wiki/Hyperbaric_medicine" title="Hyperbaric medicine">hyperbaric oxygen chamber</a> to slow aging',
#  'href="#cite_note-Image-128">&#91;126&#93;</a></sup> They also reported that Jackson took female hormone ',
#  'href="/wiki/Elizabeth_Taylor" title="Elizabeth Taylor">Elizabeth Taylor</a> and possibly had a shrine of',
#  'href="/wiki/Frank_DiLeo" title="Frank DiLeo">Frank DiLeo</a> denied all of them, except for Jackson havi',
#  'href="/wiki/Bubbles_(chimpanzee)" title="Bubbles (chimpanzee)">Bubbles</a> to tour in Japan, the media p',
#  'href="/wiki/Disney" class="mw-redirect" title="Disney">Disney</a> cartoon character who befriended anima',
#  'href="#cite_note-130">&#91;128&#93;</a></sup> It was also reported that Jackson had offered to buy the b',
#  'href="/wiki/Joseph_Merrick" title="Joseph Merrick">Joseph Merrick</a> (the "Elephant Man").<sup id="cite',
#  'href="#cite_note-FOOTNOTETaraborrelli2009355–361-131">&#91;129&#93;</a></sup> In June 1987, the <i><a hr',
#  'href="/wiki/London_Hospital_Medical_College" class="mw-redirect" title="London Hospital Medical College"',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup><sup id="cite_ref-133" class="reference"><a href="#c',
#  'href="/wiki/Joseph_Vogel" title="Joseph Vogel">Joseph Vogel</a>, the demeaning name first appeared in Br',
#  'href="/wiki/The_Sun_(United_Kingdom)" title="The Sun (United Kingdom)">The Sun</a></i> in 1985. The name',
#  'href="/wiki/Jacco_Macacco" title="Jacco Macacco">Jacko Macacco</a>, the name of a famous monkey used in ',
#  'href="/wiki/Monkey-baiting" title="Monkey-baiting">monkey-baiting</a> matches at the Westminster Pit in ',
#  'href="/wiki/Rhyming_slang" title="Rhyming slang">Cockney slang</a> to refer to monkeys in general, hence',
#  'href="/wiki/George_Lucas" title="George Lucas">George Lucas</a> and <a href="/wiki/Francis_Ford_Coppola"',
#  'href="/wiki/3D_film" title="3D film">3D film</a> <i><a href="/wiki/Captain_EO" title="Captain EO">Captai',
#  'href="/wiki/Disneyland" title="Disneyland">Disneyland</a> and <a href="/wiki/Epcot" title="Epcot">Epcot<',
#  'href="/wiki/Tokyo_Disneyland" title="Tokyo Disneyland">Tokyo Disneyland</a> and <a href="/wiki/Disneylan',
#  'href="#cite_note-135">&#91;133&#93;</a></sup> After having been removed in the late 1990s, it returned t',
#  'href="#cite_note-136">&#91;134&#93;</a></sup> In 1987, Jackson disassociated himself from the Jehovah\'s ',
#  'href="#cite_note-137">&#91;135&#93;</a></sup> Katherine Jackson said this might have been because some W',
#  'href="#cite_note-138">&#91;136&#93;</a></sup> Michael had denounced it in a Witness publication in 1984.',
#  'href="/wiki/File:George_H._W._Bush_with_Michael_Jackson.png" class="image"><img alt="" src="//upload.wik',
#  'href="/wiki/File:George_H._W._Bush_with_Michael_Jackson.png" class="internal" title="Enlarge"></a></div>',
#  'href="/wiki/President_George_H._W._Bush" class="mw-redirect" title="President George H. W. Bush">Preside',
#  'href="/wiki/President_of_the_United_States" title="President of the United States">President of the Unit',
#  'href="/wiki/Bad_(album)" title="Bad (album)">Bad</a></i> (1987), was highly anticipated, with the indust',
#  'href="#cite_note-Time2-140">&#91;138&#93;</a></sup> It became the first album to produce five US number-',
#  'href="/wiki/I_Just_Can%27t_Stop_Loving_You" title="I Just Can&#39;t Stop Loving You">I Just Can\'t Stop L',
#  'href="/wiki/Bad_(Michael_Jackson_song)" title="Bad (Michael Jackson song)">Bad</a>", "<a href="/wiki/The',
#  'href="/wiki/Man_in_the_Mirror" title="Man in the Mirror">Man in the Mirror</a>", and "<a href="/wiki/Dir',
#  'href="/wiki/Smooth_Criminal" title="Smooth Criminal">Smooth Criminal</a>", peaked at number seven.<sup i',
#  'href="#cite_note-FourUSTop10s-61">&#91;59&#93;</a></sup> <i>Bad</i> won the 1988 Grammy for Best Enginee',
#  'href="/wiki/Grammy_Award_for_Best_Music_Video" title="Grammy Award for Best Music Video">Grammy Award fo',
#  'href="/wiki/Leave_Me_Alone_(Michael_Jackson_song)" title="Leave Me Alone (Michael Jackson song)">Leave M',
#  'href="#cite_note-grammy_mj-65">&#91;63&#93;</a></sup><sup id="cite_ref-Bruce_88-1" class="reference"><a ',
#  'href="#cite_note-Bruce-88">&#91;86&#93;</a></sup> Jackson won an Award of Achievement at the American Mu',
#  'href="#cite_note-141">&#91;139&#93;</a></sup><sup id="cite_ref-142" class="reference"><a href="#cite_not',
#  'href="#cite_note-143">&#91;141&#93;</a></sup><sup id="cite_ref-144" class="reference"><a href="#cite_not',
#  'href="/wiki/Bad_(tour)" title="Bad (tour)">Bad</a> world tour ran from September 12, 1987, to January 14',
#  'href="#cite_note-FOOTNOTELewis_Jones200595–96-145">&#91;143&#93;</a></sup> In Japan, the tour had 14 sel',
#  'href="#cite_note-146">&#91;144&#93;</a></sup> The 504,000 people who attended seven sold-out shows at <a',
#  'href="/wiki/Wembley_Stadium_(1923)" title="Wembley Stadium (1923)">Wembley Stadium</a> set a new <a href',
#  'href="/wiki/Moonwalk_(book)" title="Moonwalk (book)">Moonwalk</a></i>, with input from Stephen Davis and',
#  'href="/wiki/Jacqueline_Kennedy_Onassis" title="Jacqueline Kennedy Onassis">Jacqueline Kennedy Onassis</a',
#  'href="#cite_note-148">&#91;146&#93;</a></sup> It sold 200,000 copies,<sup id="cite_ref-149" class="refer',
#  'href="#cite_note-149">&#91;147&#93;</a></sup> and reached the top of the <i>New York Times</i> bestselle',
#  'href="#cite_note-150">&#91;148&#93;</a></sup> Jackson discussed his childhood, the Jackson 5, and the ab',
#  'href="#cite_note-FOOTNOTEJackson200929–31-151">&#91;149&#93;</a></sup> He attributed his changing facial',
#  'href="#cite_note-152">&#91;150&#93;</a></sup><sup id="cite_ref-FOOTNOTEJackson2009229–230_125-1" class="',
#  'href="#cite_note-FOOTNOTEJackson2009229–230-125">&#91;123&#93;</a></sup> In June, Jackson was honoured w',
#  'href="/wiki/Medal_of_the_City_of_Paris" title="Medal of the City of Paris">Medal of the City of Paris</a',
#  'href="/wiki/Jacques_Chirac" title="Jacques Chirac">Jacques Chirac</a> during his stay in the city as par',
#  'href="/wiki/Bad_(tour)" title="Bad (tour)">Bad</a> world tour.<sup id="cite_ref-153" class="reference"><',
#  'href="#cite_note-153">&#91;151&#93;</a></sup><sup id="cite_ref-154" class="reference"><a href="#cite_not',
#  'href="/wiki/Moonwalker" title="Moonwalker">Moonwalker</a></i>, which featured live footage and short fil',
#  'href="/wiki/Joe_Pesci" title="Joe Pesci">Joe Pesci</a>. In the US it was released <a href="/wiki/Direct-',
#  'href="#cite_note-155">&#91;153&#93;</a></sup><sup id="cite_ref-156" class="reference"><a href="#cite_not',
#  'href="/wiki/Recording_Industry_Association_of_America" title="Recording Industry Association of America"',
#  'href="/wiki/Santa_Ynez,_California" title="Santa Ynez, California">Santa Ynez, California</a>, to build ',
#  'href="/wiki/Neverland_Ranch" title="Neverland Ranch">Neverland Ranch</a>, at a cost of $17<span class="n',
#  'href="#cite_note-Malta-158">&#91;156&#93;</a></sup> He installed a <a href="/wiki/Ferris_wheel" title="F',
#  'href="/wiki/Carousel" title="Carousel">carousel</a>, a movie theater and a zoo.<sup id="cite_ref-Malta_1',
#  'href="#cite_note-Malta-158">&#91;156&#93;</a></sup><sup id="cite_ref-Bio2_159-0" class="reference"><a hr',
#  'href="#cite_note-160">&#91;158&#93;</a></sup> A security staff of 40 patrolled the grounds.<sup id="cite',
#  'href="#cite_note-Bio2-159">&#91;157&#93;</a></sup> Shortly afterwards, he appeared in the first Western ',
#  'href="/wiki/Soviet_Union" title="Soviet Union">Soviet Union</a>.<sup id="cite_ref-161" class="reference"',
#  'href="/wiki/Honorific_nicknames_in_popular_music" title="Honorific nicknames in popular music">King of P',
#  'href="#cite_note-FOOTNOTELewis_Jones2005165–168-26">&#91;24&#93;</a></sup><sup id="cite_ref-FOOTNOTETann',
#  'href="#cite_note-FOOTNOTETannenbaumMarks2011Chapter_41,_&quot;I_Want_to_Have_a_Nickname&quot;-162">&#91;',
#  'href="#cite_note-ew1991-163">&#91;161&#93;</a></sup> When <a href="/wiki/Elizabeth_Taylor" title="Elizab',
#  'href="#cite_note-FOOTNOTECampbell1993260–263-164">&#91;162&#93;</a></sup> President <a href="/wiki/Georg',
#  'href="#cite_note-165">&#91;163&#93;</a></sup> From 1985 to 1990, Jackson donated $455,000 to the <a href',
#  'href="#cite_note-166">&#91;164&#93;</a></sup> and all profits from his single "Man in the Mirror" went t',
#  'href="#cite_note-FOOTNOTETaraborrelli2009382-167">&#91;165&#93;</a></sup> His rendition of "You Were The',
#  'href="/wiki/Sammy_Davis_Jr." title="Sammy Davis Jr.">Sammy Davis Jr.</a>\'s 60th birthday celebration won',
#  'href="#cite_note-emmys.tv-81">&#91;79&#93;</a></sup> Jackson was the bestselling artist of the 1980s.<su',
#  'href="#cite_note-169">&#91;167&#93;</a></sup> beating <a href="/wiki/Neil_Diamond" title="Neil Diamond">',
#  'href="/wiki/Columbia_Records" title="Columbia Records">Columbia Records</a>.<sup id="cite_ref-170" class',
#  'href="#cite_note-170">&#91;168&#93;</a></sup> In 1991, he released his eighth album, <i><a href="/wiki/D',
#  'href="/wiki/Teddy_Riley" title="Teddy Riley">Teddy Riley</a>.<sup id="cite_ref-171" class="reference"><a',
#  'href="#cite_note-171">&#91;169&#93;</a></sup> It was certified eight times platinum in the US, and by 20',
#  'href="#cite_note-Certifications-172">&#91;170&#93;</a></sup><sup id="cite_ref-173" class="reference"><a ',
#  'href="#cite_note-173">&#91;171&#93;</a></sup> In the US, the first single, "<a href="/wiki/Black_or_Whit',
#  'href="#cite_note-Achievements-174">&#91;172&#93;</a></sup> The second single, "<a href="/wiki/Remember_t',
#  'href="#cite_note-billboard_mj-175">&#91;173&#93;</a></sup> At the end of 1992, <i>Dangerous</i> was the ',
#  'href="/wiki/Billboard_Music_Award" class="mw-redirect" title="Billboard Music Award"><i>Billboard</i> Mu',
#  'href="#cite_note-Brooks-168">&#91;166&#93;</a></sup> In 1993, he performed "Remember the Time" at the <a',
#  'href="/wiki/Soul_Train_Music_Awards" title="Soul Train Music Awards">Soul Train Music Awards</a> in a ch',
#  'href="#cite_note-176">&#91;174&#93;</a></sup> In the UK, "<a href="/wiki/Heal_the_World" title="Heal the',
#  'href="/wiki/File:Michael_Jackson_Dangerous_World_Tour_1993.jpg" class="image"><img alt="" src="//upload.',
#  'href="/wiki/File:Michael_Jackson_Dangerous_World_Tour_1993.jpg" class="internal" title="Enlarge"></a></d',
#  'href="/wiki/Dangerous_World_Tour" title="Dangerous World Tour">Dangerous World Tour</a> in 1993. <i><a h',
#  'href="/wiki/Heal_the_World_Foundation" title="Heal the World Foundation">Heal the World Foundation</a> i',
#  'href="/wiki/Dancing_the_Dream" title="Dancing the Dream">Dancing the Dream</a>,</i> a collection of poet',
#  'href="/wiki/Dangerous_World_Tour" title="Dangerous World Tour">Dangerous World Tour</a> ran between June',
#  'href="#cite_note-179">&#91;177&#93;</a></sup> Part of the proceeds went to Heal the World Foundation.<su',
#  'href="#cite_note-180">&#91;178&#93;</a></sup> Jackson sold the broadcast rights of the tour to <a href="',
#  'href="/wiki/HIV/AIDS" title="HIV/AIDS">HIV/AIDS</a> spokesperson and friend <a href="/wiki/Ryan_White" t',
#  'href="/wiki/First_inauguration_of_Bill_Clinton" title="First inauguration of Bill Clinton">Bill Clinton\'',
# ...
#  'href="#cite_note-FOOTNOTEBrackettHoard2004414-428">&#91;425&#93;</a></sup> He was known for his vocal ra',
#  'href="#cite_note-429">&#91;426&#93;</a></sup> With the arrival of <i>Off the Wall</i> in the late 1970s,',
#  'href="/wiki/Falsetto" title="Falsetto">falsetto</a> that\'s used very daringly."<sup id="cite_ref-430" cl',
#  'href="#cite_note-430">&#91;427&#93;</a></sup> By the time of 1982\'s <i>Thriller</i>, <i>Rolling Stone</i',
#  'href="#cite_note-NYT_Dangerous-432">&#91;429&#93;</a></sup> Of <i>Invincible</i>, <i>Rolling Stone</i> w',
#  'href="#cite_note-433">&#91;430&#93;</a></sup> <a href="/wiki/Joseph_Vogel" title="Joseph Vogel">Joseph V',
#  'href="#cite_note-FOOTNOTEVogel20129-434">&#91;431&#93;</a></sup> <a href="/wiki/Neil_McCormick" title="N',
#  'href="/wiki/Musical_notation" title="Musical notation">music notation</a>. He is credited for playing gu',
#  'href="#cite_note-NME-436">&#91;433&#93;</a></sup> When composing, he recorded ideas by beatboxing and im',
#  'href="#cite_note-NME-436">&#91;433&#93;</a></sup> Describing the process, he said: "I\'ll just sing the b',
#  'href="#cite_note-Sanjoy-437">&#91;434&#93;</a></sup> and incorporated dance extensively in his performan',
#  'href="#cite_note-Sanjoy-437">&#91;434&#93;</a></sup> According to Sanjoy Roy of <i><a href="/wiki/The_Gu',
#  'href="#cite_note-Sanjoy-437">&#91;434&#93;</a></sup> The <a href="/wiki/Moonwalk_(dance)" title="Moonwal',
#  'href="/wiki/Jeffrey_Daniel" title="Jeffrey Daniel">Jeffrey Daniel</a>,<sup id="cite_ref-Daniel_83-1" cla',
#  'href="#cite_note-Daniel-83">&#91;81&#93;</a></sup> was Jackson\'s signature dance move and one of the mos',
#  'href="#cite_note-438">&#91;435&#93;</a></sup> Jackson is credited for coining the name "moonwalk"; the m',
#  'href="#cite_note-439">&#91;436&#93;</a></sup><sup id="cite_ref-440" class="reference"><a href="#cite_not',
#  'href="/wiki/Robot_(dance)" title="Robot (dance)">robot</a>,<sup id="cite_ref-FOOTNOTEMansour2005403_51-1',
#  'href="#cite_note-FOOTNOTEMansour2005403-51">&#91;49&#93;</a></sup> crotch grab, and the "anti-gravity" l',
#  'href="/wiki/File:Michael_Jackson1_1988.jpg" class="image"><img alt="Black and white photo of Jackson hol',
#  'href="/wiki/File:Michael_Jackson1_1988.jpg" class="internal" title="Enlarge"></a></div>Jackson during hi',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup><sup id="cite_ref-Jet_441-0" class="reference"><a hr',
#  'href="/wiki/Soul_music" title="Soul music">soul</a>,<sup id="cite_ref-allmusic_12-4" class="reference"><',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup><sup id="cite_ref-Bio2_159-2" class="reference"><a h',
#  'href="/wiki/Rhythm_and_blues" title="Rhythm and blues">rhythm and blues</a>,<sup id="cite_ref-Jet_441-1"',
#  'href="#cite_note-Jet-441">&#91;438&#93;</a></sup> <a href="/wiki/Funk" title="Funk">funk</a>,<sup id="ci',
#  'href="#cite_note-Help-442">&#91;439&#93;</a></sup> rock,<sup id="cite_ref-Jet_441-2" class="reference"><',
#  'href="#cite_note-Jet-441">&#91;438&#93;</a></sup><sup id="cite_ref-Help_442-1" class="reference"><a href',
#  'href="/wiki/Disco" title="Disco">disco</a>,<sup id="cite_ref-AMOFW_443-0" class="reference"><a href="#ci',
#  'href="/wiki/Post-disco" title="Post-disco">post-disco</a>,<sup id="cite_ref-Help_442-2" class="reference',
#  'href="#cite_note-Help-442">&#91;439&#93;</a></sup> <a href="/wiki/Dance-pop" title="Dance-pop">dance-pop',
#  'href="#cite_note-FOOTNOTEPalmer1995285-444">&#91;441&#93;</a></sup> and <a href="/wiki/New_jack_swing" t',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup> Steve Huey of <a href="/wiki/AllMusic" title="AllMu',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup> Its tracks included the ballads "The Lady in My Lif',
#  'href="/wiki/Human_Nature_(Michael_Jackson_song)" title="Human Nature (Michael Jackson song)">Human Natur',
#  'href="/wiki/The_Girl_Is_Mine" title="The Girl Is Mine">The Girl Is Mine</a>",<sup id="cite_ref-AMThrille',
#  'href="#cite_note-AMThriller-445">&#91;442&#93;</a></sup><sup id="cite_ref-Thriller_431-1" class="referen',
#  'href="#cite_note-Thriller-431">&#91;428&#93;</a></sup><sup id="cite_ref-Slant_446-0" class="reference"><',
#  'href="#cite_note-Slant-446">&#91;443&#93;</a></sup> the funk pieces "Billie Jean" and "Wanna Be Startin\'',
#  'href="#cite_note-AMThriller-445">&#91;442&#93;</a></sup><sup id="cite_ref-Thriller_431-2" class="referen',
#  'href="#cite_note-Thriller-431">&#91;428&#93;</a></sup> and the disco set "<a href="/wiki/Baby_Be_Mine_(M',
#  'href="/wiki/P.Y.T._(Pretty_Young_Thing)" title="P.Y.T. (Pretty Young Thing)">P.Y.T. (Pretty Young Thing)',
#  'href="/wiki/Robert_Christgau" title="Robert Christgau">Robert Christgau</a> wrote in <i><a href="/wiki/C',
#  'href="/wiki/Stevie_Wonder" title="Stevie Wonder">Stevie Wonder</a>\'s "oddball" music personas: "Since ch',
#  'href="#cite_note-FOOTNOTEChristgau1981Consumer_Guide_&#39;70s:_J-447">&#91;444&#93;</a></sup> With <i>Th',
#  'href="/wiki/Paranoia" title="Paranoia">paranoia</a> and darker imagery.<sup id="cite_ref-Thriller_431-3"',
#  'href="#cite_note-Thriller-431">&#91;428&#93;</a></sup> AllMusic\'s <a href="/wiki/Stephen_Thomas_Erlewine',
#  'href="#cite_note-AMThriller-445">&#91;442&#93;</a></sup> In "Billie Jean", Jackson depicts an obsessive ',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup> and in "Wanna Be Startin\' Somethin\'" he argues agai',
#  'href="#cite_note-Thriller-431">&#91;428&#93;</a></sup> "Beat It" decried gang violence in a homage to <i',
#  'href="/wiki/West_Side_Story" title="West Side Story">West Side Story</a></i>, and was Jackson\'s first su',
#  'href="#cite_note-allmusic-12">&#91;10&#93;</a></sup><sup id="cite_ref-Bio_43-1" class="reference"><a hre',
#  'href="/wiki/Thriller_(song)" title="Thriller (song)">Thriller</a>" began Jackson\'s interest with the the',
#  'href="/wiki/Supernatural" title="Supernatural">supernatural</a>, a topic he revisited in subsequent year',
#  'href="/wiki/File:Michael_Jackson_Thriller.ogg" title="File:Michael Jackson Thriller.ogg">"Thriller"</a><',
#  'href="#cite_note-FOOTNOTEGeorge200423-448">&#91;445&#93;</a></sup></div></div><hr /><div class="haudio">',
#  'href="/wiki/File:Smooth_Criminal_by_Michael_Jackson.ogg" title="File:Smooth Criminal by Michael Jackson.',
#  'href="#cite_note-FOOTNOTEGeorge200424-449">&#91;446&#93;</a></sup></div></div><hr /><div class="haudio">',
#  'href="/wiki/File:Michael_Jackson_-_Black_Or_White.ogg" title="File:Michael Jackson - Black Or White.ogg"',
#  'href="#cite_note-450">&#91;447&#93;</a></sup><sup id="cite_ref-FOOTNOTERamageBeanJohnson2001491_451-0" c',
#  'href="#cite_note-452">&#91;449&#93;</a></sup> The lead single "I Just Can\'t Stop Loving You" is a tradit',
#  'href="/wiki/Smooth_Criminal" title="Smooth Criminal">Smooth Criminal</a>" is an evocation of bloody assa',
#  'href="#cite_note-Time2-140">&#91;138&#93;</a></sup> AllMusic\'s Stephen Thomas Erlewine states that <i>Da',
#  'href="#cite_note-Dangerous-453">&#91;450&#93;</a></sup> The first half of the record is dedicated to new',
#  'href="/wiki/In_the_Closet" title="In the Closet">In the Closet</a>". The title track continues the theme',
#  'href="/wiki/Will_You_Be_There" title="Will You Be There">Will You Be There</a>", "Heal the World" and "K',
#  'href="#cite_note-NYT_Dangerous-432">&#91;429&#93;</a></sup> In the ballad "<a href="/wiki/Gone_Too_Soon"',
#  'href="#cite_note-AMHIStory-455">&#91;452&#93;</a></sup> In the new jack swing-funk rock tracks "Scream" ',
#  'href="/wiki/You_Are_Not_Alone" title="You Are Not Alone">You Are Not Alone</a>", Jackson retaliates agai',
#  'href="#cite_note-RSHIStory-456">&#91;453&#93;</a></sup> In the introspective ballad "<a href="/wiki/Stra',
#  'href="#cite_note-AMHIStory-455">&#91;452&#93;</a></sup><sup id="cite_ref-RSHIStory_456-1" class="referen',
#  'href="#cite_note-RSHIStory-456">&#91;453&#93;</a></sup> In "<a href="/wiki/D.S._(song)" title="D.S. (son',
#  'href="/wiki/Thomas_W._Sneddon_Jr." title="Thomas W. Sneddon Jr.">Thomas W. Sneddon Jr.</a>, who had pros',
#  'href="#cite_note-457">&#91;454&#93;</a></sup> <i>Invincible</i> includes urban soul tracks such as "<a h',
#  'href="/wiki/Speechless_(Michael_Jackson_song)" title="Speechless (Michael Jackson song)">Speechless</a>"',
#  'href="#cite_note-458">&#91;455&#93;</a></sup><sup id="cite_ref-459" class="reference"><a href="#cite_not',
#  'href="/wiki/File:Michaeljacksonphoto_drewcohen.JPG" class="image"><img alt="A man is singing into a micr',
#  'href="/wiki/File:Michaeljacksonphoto_drewcohen.JPG" class="internal" title="Enlarge"></a></div>Jackson (',
#  'href="/wiki/The_Way_You_Make_Me_Feel" title="The Way You Make Me Feel">The Way You Make Me Feel</a>" at ',
#  'href="/wiki/Michael_Jackson%27s_Thriller_(music_video)" title="Michael Jackson&#39;s Thriller (music vid',
#  'href="/wiki/John_Landis" title="John Landis">John Landis</a>, in 1983.<sup id="cite_ref-Registry_460-0" ',
#  'href="#cite_note-Registry-460">&#91;457&#93;</a></sup> The <a href="/wiki/Zombie" title="Zombie">zombie<',
#  'href="/wiki/MTV" title="MTV">MTV</a>, which had launched two years earlier.<sup id="cite_ref-FOOTNOTEYou',
#  'href="#cite_note-FOOTNOTEYoung200925-46">&#91;44&#93;</a></sup> Before <i>Thriller</i>, Jackson struggle',
#  'href="#cite_note-461">&#91;458&#93;</a></sup> Pressure from CBS Records persuaded MTV to start showing "',
#  'href="#cite_note-Video-462">&#91;459&#93;</a></sup> The popularity of his videos on MTV helped the relat',
#  'href="#cite_note-Video-462">&#91;459&#93;</a></sup><sup id="cite_ref-463" class="reference"><a href="#ci',
#  'href="#cite_note-FOOTNOTEInglis2006119,_127-464">&#91;461&#93;</a></sup> The choreography in <i>Thriller',
#  'href="/wiki/Cinema_of_India" title="Cinema of India">Indian films</a> and <a href="/wiki/Thriller_(viral',
#  'href="#cite_note-465">&#91;462&#93;</a></sup> <i>Thriller</i> marked an increase in scale for music vide',
#  'href="/wiki/Martin_Scorsese" title="Martin Scorsese">Martin Scorsese</a>—Jackson used sexual imagery and',
#  'href="/wiki/Wesley_Snipes" title="Wesley Snipes">Wesley Snipes</a>; Jackson\'s later videos often feature',
#  'href="#cite_note-FOOTNOTETaraborrelli2009370–373-466">&#91;463&#93;</a></sup><sup id="cite_ref-467" clas',
#  'href="#cite_note-467">&#91;464&#93;</a></sup> For the "Smooth Criminal" video, Jackson experimented with',
#  'href="http://patft.uspto.gov/netacgi/nph-Parser?patentnumber=5255452">U.S. Patent 5,255,452</a></span> f',
#  'href="#cite_note-468">&#91;465&#93;</a></sup> The video for "Leave Me Alone" was not officially released',
#  'href="#cite_note-FOOTNOTECampbell1993273-469">&#91;466&#93;</a></sup> and won a Golden Lion Award for it',
#  'href="/wiki/Grammy_Award_for_Best_Music_Video" title="Grammy Award for Best Music Video">Best Music Vide',
#  'href="/wiki/Michael_Jackson_Video_Vanguard_Award" title="Michael Jackson Video Vanguard Award">MTV Video',
#  'href="#cite_note-MTV2-470">&#91;467&#93;</a></sup> The "Black or White" video simultaneously premiered o',
#  'href="#cite_note-Achievements-174">&#91;172&#93;</a></sup> Along with Jackson, it featured <a href="/wik',
#  'href="/wiki/Peggy_Lipton" title="Peggy Lipton">Peggy Lipton</a>, and <a href="/wiki/George_Wendt" title=',
#  'href="/wiki/Morphing" title="Morphing">morphing</a> to music videos.<sup id="cite_ref-FOOTNOTECampbell19',
#  'href="#cite_note-FOOTNOTECampbell1993303-471">&#91;468&#93;</a></sup> It was controversial for scenes in',
#  'href="/wiki/Naomi_Campbell" title="Naomi Campbell">Naomi Campbell</a> in a courtship dance with Jackson.',
#  'href="#cite_note-472">&#91;469&#93;</a></sup> "Remember the Time" was set in <a href="/wiki/Ancient_Egyp',
#  'href="/wiki/Eddie_Murphy" title="Eddie Murphy">Eddie Murphy</a>, <a href="/wiki/Iman_(model)" title="Ima',
#  'href="/wiki/Magic_Johnson" title="Magic Johnson">Magic Johnson</a>.<sup id="cite_ref-FOOTNOTECampbell199',
#  'href="#cite_note-FOOTNOTECampbell1993313–314-473">&#91;470&#93;</a></sup> The video for "Scream", direct',
#  'href="/wiki/Mark_Romanek" title="Mark Romanek">Mark Romanek</a> and production designer Tom Foden, gaine',
#  'href="/wiki/MTV_Video_Music_Award" class="mw-redirect" title="MTV Video Music Award">MTV Video Music Awa',
#  'href="#cite_note-FOOTNOTEBoepple199552-474">&#91;471&#93;</a></sup> The song and its video are Jackson\'s',
#  'href="#cite_note-475">&#91;472&#93;</a></sup> A year later, it won a Grammy for Best Music Video, Short ',
#  'href="/wiki/List_of_most_expensive_music_videos" title="List of most expensive music videos">most expens',
#  'href="#cite_note-476">&#91;473&#93;</a></sup> Romanek has contradicted this.<sup id="cite_ref-477" class',
#  'href="#cite_note-477">&#91;474&#93;</a></sup> The "Earth Song" video was nominated for the 1997 Grammy f',
#  'href="/wiki/Michael_Jackson%27s_Ghosts" title="Michael Jackson&#39;s Ghosts">Michael Jackson\'s Ghosts</a',
#  'href="/wiki/Stephen_King" title="Stephen King">Stephen King</a> and directed by <a href="/wiki/Stan_Wins',
#  'href="/wiki/Cannes_Film_Festival" title="Cannes Film Festival">Cannes Film Festival</a>. At over 38 minu',
#  'href="/wiki/Pharrell_Williams" title="Pharrell Williams">Pharrell Williams</a> song "<a href="/wiki/Happ',
#  'href="#cite_note-479">&#91;476&#93;</a></sup> The 2001 video for "<a href="/wiki/You_Rock_My_World" titl',
#  'href="/wiki/Paul_Hunter_(director)" title="Paul Hunter (director)">Paul Hunter</a>, and features <a href',
#  'href="/wiki/Marlon_Brando" title="Marlon Brando">Marlon Brando</a>.<sup id="cite_ref-480" class="referen',
#  'href="#cite_note-480">&#91;477&#93;</a></sup> It won an <a href="/wiki/NAACP_Image_Award" class="mw-redi',
#  'href="/wiki/Library_of_Congress" title="Library of Congress">Library of Congress</a> selected "Thriller"',
#  'href="/wiki/National_Film_Registry" title="National Film Registry">National Film Registry</a>, as a work',
#  'href="#cite_note-482">&#91;479&#93;</a></sup><sup id="cite_ref-NYT_483-0" class="reference"><a href="#ci',
#  'href="mw-data:TemplateStyles:r1033289096"/><div role="note" class="hatnote navigation-not-searchable">Se',
#  'href="/wiki/List_of_awards_and_nominations_received_by_Michael_Jackson" title="List of awards and nomina',
#  'href="/wiki/Philanthropy_of_Michael_Jackson" title="Philanthropy of Michael Jackson">Philanthropy of Mic',
#  'href="/wiki/File:Thriller_platinum_record,_Hard_Rock_Cafe_Hollywood.JPG" class="image"><img alt="" src="',
#  'href="/wiki/File:Thriller_platinum_record,_Hard_Rock_Cafe_Hollywood.JPG" class="internal" title="Enlarge',
#  'href="/wiki/RIAA_certification" title="RIAA certification">platinum</a> certified record on display at t',
#  'href="/wiki/Hard_Rock_Cafe" title="Hard Rock Cafe">Hard Rock Cafe</a> in <a href="/wiki/Hollywood,_Los_A',
#  'href="#cite_note-484">&#91;481&#93;</a></sup><sup class="reference" id="ref_Note_2"><a href="#endnote_No',
#  'href="/wiki/List_of_best-selling_music_artists" title="List of best-selling music artists">best-selling ',
#  'href="#cite_note-485">&#91;482&#93;</a></sup> He had 13 <a href="/wiki/List_of_artists_who_reached_numbe',
#  'href="#cite_note-486">&#91;483&#93;</a></sup> The <a href="/wiki/Recording_Industry_Association_of_Ameri',
#  'href="#cite_note-RIAA-8">&#91;7&#93;</a></sup> He was invited and honored by a <a href="/wiki/President_',
#  'href="/wiki/White_House" title="White House">White House</a> three times. In 1984, he was honored with a',
#  'href="/wiki/Ronald_Reagan" title="Ronald Reagan">Ronald Reagan</a> for his humanitarian endeavors.<sup i',
#  'href="#cite_note-487">&#91;484&#93;</a></sup> In 1990, he was honored as the "Artist of the Decade" by <',
#  'href="/wiki/George_H._W._Bush" title="George H. W. Bush">George H. W. Bush</a>.<sup id="cite_ref-FOOTNOT',
#  'href="#cite_note-FOOTNOTEGeorge200444–45-488">&#91;485&#93;</a></sup> In 1992, he was honored as a "Poin',
#  'href="/wiki/Neverland_Ranch" title="Neverland Ranch">Neverland Ranch</a>.<sup id="cite_ref-FOOTNOTECampb',
#  'href="/wiki/List_of_awards_and_nominations_received_by_Michael_Jackson" title="List of awards and nomina',
#  ...]

# %%
# You will automate this part for your project
song_links = ['/wiki/Blood_on_the_Dance_Floor_(song)',
              '/wiki/Thriller_(song)',
              '/wiki/Jam_(song)']

# %%
for counter, link in enumerate(song_links):
    url = 'https://en.wikipedia.org' + link
    response = requests.get(url)
    with open(f'{counter}.txt', 'w', encoding='utf-8') as f:
        f.write(response.text)
    print(counter, link, response.status_code)
# Out:
# 0 /wiki/Blood_on_the_Dance_Floor_(song) 200
# 1 /wiki/Thriller_(song) 200
# 2 /wiki/Jam_(song) 200

# %%
for counter, link in enumerate(song_links):
    url = 'https://en.wikipedia.org' + link
    response = requests.get(url)
    song_title = link.split('/')[2]
    with open(f'{song_title}.txt', 'w', encoding='utf-8') as f:
        f.write(response.text)
    print(counter, song_title, response.status_code)
# Out:
# 0 Blood_on_the_Dance_Floor_(song) 200
# 1 Thriller_(song) 200
# 2 Jam_(song) 200

# %% [markdown]
# You have two options:
# * You could save the full html of your song page into a file
# * You can do some more web scraping magic and extraxt just the lyrics and save that into a file
